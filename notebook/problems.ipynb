# %% [markdown]
# # Probability Distribution Problems

# %% [markdown]
# **Binomial Distribution**
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either Head or Tails.

# %%
# Probability functions, density and distribution

def dbinom(x,size,prob=0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.pmf(k=x,n=size,p=prob,loc=0)
    return result

def pbinom(q,size,prob=0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    from scipy.stats import binom
    result=binom.cdf(k=q,n=size,p=prob,loc=0)
    return result

def qbinom(p, size, prob=0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.ppf(q=p,n=size,p=prob,loc=0)
    return result

def rbinom(n,size,prob=0.5):
    """
    Generates random variables from the binomial distribution
    """
    from scipy.stats import binom
    result=binom.rvs(n=size,p=prob,size=n)
    return result

# %%
dbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) takes the value 2,
pbinom(2, size = 10, prob = 0.2) #Probability that a binomial (10,0.2) will take a value less than 2
qbinom(0.9, size = 10, prob = 0.2) # what value of a binomial (10,0.2) has a cumulative probability of 0.9?
rbinom(2000, size = 10, prob = 0.2) # generate 2000 random values from a binomial distribution (10,0.2)
# Out:
# array([1, 1, 1, ..., 1, 4, 2])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Discrete distributions
xs = np.arange( 1, 11 )
ys = dbinom(xs,size=10,prob=0.5) # compute the shape of the distribution
plt.plot( xs, ys, 'o' )   # plot circles...
plt.vlines( xs, 0, ys )   # ...and lines
plt.ylim( bottom=0 )      # ensure sensible bottom border
plt.title('Probability function binomial distribution')
plt.show()

# %% [markdown]
# Exercise 1: Create the same functions but for the normal and uniform distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def dnorm(x,mean=0,sd =1):
    """
    Calculates the density of the Normal distribution
    """
    from scipy.stats import norm
    result=norm.pdf(x,loc=mean,scale=sd)
    return result

def pnorm(q,mean=0,sd=1):
    """
    Calculates the cumulative of the normal distribution
    """
    from scipy.stats import norm
    result=norm.cdf(x=q,loc=mean,scale=sd)
    return result

def qnorm(p,mean=0,sd=1):
    """
    Calculates the quantile function of the normal distribution
    """
    from scipy.stats import norm
    result=norm.ppf(q=p,loc=mean,scale=sd)
    return result

def rnorm(n,mean=0,sd=1):
    """
    Generates random variables from the normal distribution
    """
    from scipy.stats import norm
    result=norm.rvs(size=n,loc=mean,scale=sd)
    return result

# %%
# Continuous distributions
x = np.arange(-6,6,0.1)
plt.plot(x,dnorm(x,mean=0,sd=1))
plt.show()

# %%
x = np.arange(-6,6,0.1)
plt.plot(x,pnorm(x,mean=0,sd=1))
plt.show()

# %%
x = np.arange(-6,6,0.1)
plt.plot(x,qnorm(x,mean=0,sd=1))
plt.show()

# %%
aleatorios_1 = rnorm(10000) 
Normal_2 = plt.hist(aleatorios_1, 30)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Normal')
plt.show()

# %%
# Graficando histograma de la distribucion normal 
mu, sigma = 0, 0.2 # media y desvio estandar
datos = np.random.normal(mu, sigma, 10000) #creando muestra de datos

# histograma de distribución normal.
cuenta, cajas, ignorar = plt.hist(datos, 20)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma')
plt.show()

# %%
from scipy.stats import norm

# %%
# Graficando Función de Distribución Acumulada con Python
x_1 = np.linspace(norm(8, 3).ppf(0.02),
                  norm(8, 3).ppf(0.98), 100)
fda_normal = norm(8, 3).cdf(x_1) # Función de Distribución Acumulada
plt.plot(x_1, fda_normal, label='FDA nomal')
plt.title('Función de Distribución Acumulada')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.legend(loc=4)
plt.show()

# %%
# Graficando Función de Densidad de Probibilidad con Python
# es la derivada de la función de distribución acumulada
FDP_normal = norm(8, 3).pdf(x_1) # FDP
plt.plot(x_1, FDP_normal, label='FDP nomal')
plt.title('Función de Densidad de Probabilidad')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# Graficando Normal
# distribuciones continuas 
mu, sigma = 1, 0.5 # media y desvio estandar
normal = norm(mu, sigma)
x = np.linspace(normal.ppf(0.02),
                normal.ppf(0.98), 100)
fp = normal.pdf(x) # Función de Probabilidad
plt.plot(x, fp)
plt.title('Distribución Normal')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma Normal 
aleatorios = normal.rvs(10000) # genera aleatorios
Normal_1 = plt.hist(aleatorios, 30)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Normal')
plt.show()

# %%
def duniform(x):
    """
    Calculates the density of the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.pdf(x, 0, 5)
    return result

def puniform(x):
    """
    Calculates the cumulative of the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.cdf(x, 0, 5)
    return result


def quniform(x):
    """
    Calculates the quantile function of the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.ppf(x, 0 , 5)
    return result

def runiform(X):
    """
    Generates random variables from the uniform distribution
    """
    from scipy.stats import uniform
    result=uniform.rvs(x)
    return result

# %%
x = np.arange(-1, 6, 0.1)
y =duniform(x)
plt.plot(x, y) 
plt.show()

# %%
x = np.arange(-1, 6, 0.1)
y =puniform(x)
plt.plot(x, y) 
plt.show()

# %%
formula= runiform(10000)
Uniforme_2 = plt.hist(formula, 30)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Uniforme')
plt.show()

# %%
from scipy.stats import uniform

# %%
# Graficando Uniforme
# The uniform.pdf() function measures probability density function (pdf) of the distribution.
uniforme = uniform()
x = np.linspace(uniforme.ppf(0.02),
                uniforme.ppf(0.98), 100)
fp = uniforme.pdf(x) # Función de Probabilidad
fig, ax = plt.subplots()
ax.plot(x, fp, '--')
ax.vlines(x, 0, fp, colors='b', lw=5, alpha=0.5)
ax.set_yticks([0., 0.2, 0.4, 0.6, 0.8, 1., 1.2])
plt.title('Distribución Uniforme')
plt.ylabel('probabilidad')
plt.xlabel('valores')
plt.show()

# %%
# histograma
#The uniform.rvs() function generates an array containing specified number of random numbers of the given uniform distribution. In the example below, a histogram is plotted to visualize the result.
aleatorios = uniforme.rvs(1000) # genera aleatorios
Uniforme_1 = plt.hist(aleatorios, 30)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma Uniforme')
plt.show()

# %%
# The uniform.cdf() function returns cumulative distribution function (cdf) of the distribution.

#creating an array of values between
#-1 to 6 with a difference of 0.1
x = np.arange(-1, 6, 0.1)
   
y = uniform.cdf(x, 0, 5)
   
plt.plot(x, y) 
plt.show()

# %%
# The uniform.ppf() function takes the probability value and returns cumulative value corresponding to probability value of the distribution.

#creating an array of probability from
#0 to 1 with a difference of 0.01
x = np.arange(0, 1, 0.01)
   
y = uniform.ppf(x, 0, 5)
   
plt.plot(x, y) 
plt.show()
